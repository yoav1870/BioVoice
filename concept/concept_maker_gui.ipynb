# %%
# %matplotlib widget
import ipympl
from pathlib import Path
from concept_maker import launch_concept_maker,launch_concept_maker_like_concepts_creation

FREQUENCY_BIN_COUNT = 72
HOP_LENGTH = 240
SAMPLE_RATE = 16000

# cm = launch_concept_maker(
#     mel_bins=FREQUENCY_BIN_COUNT,
#     frames=304,          
#     hop_length=HOP_LENGTH,
#     sample_rate=SAMPLE_RATE,
#     out_dir=Path("/home/SpeakerRec/BioVoice/concept/new_concepts"),
# )
launch_concept_maker_like_concepts_creation(
    out_dir=Path("/home/SpeakerRec/BioVoice/concept/new_concepts_3_2_2026"),
)
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
